# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import KFold, cross_val_score
import pandas as pd

# %%
df = pd.read_csv('../../Labs/data/lab05/q01.csv')[['restecg', 'oldpeak', 'target']]

df
# Out:
#       restecg  oldpeak  target
# 0           1      1.0       0
# 1           0      3.1       0
# 2           1      2.6       0
# 3           1      0.0       0
# 4           1      1.9       0
# ...       ...      ...     ...
# 1020        1      0.0       1
# 1021        0      2.8       0
# 1022        0      1.0       0
# 1023        0      0.0       1
# 1024        1      1.4       0
#
# [1025 rows x 3 columns]

# %%
model = BaggingClassifier(DecisionTreeClassifier(random_state=0))

kf = KFold(n_splits=5, shuffle=False)

X = df.drop(columns=['target'])
y = df['target']

print('Score:', cross_val_score(model, X, y, cv=kf))
# Out:
# Score: [0.75609756 0.78536585 0.72682927 0.73170732 0.69756098]
